# %%
# %reload_ext blackcellmagic
import pandas as pd
import numpy as np
import os
import pprint as pp
import matplotlib.pyplot as plt

# %%
def get_var(df, var):
     return df[df['VAR'] == var]

    
def fix_time(time_list):
    for i in time_list:
        i = str(i)
        if i.startswith('Q2-'):
            index = time_list.index(i)
            q2 = i.replace('Q2-', '')
            q2 = int(q2)
            time_list.pop(index)
            time_list.insert(q2, index)
        elif i.startswith('Q4-'):
            index = time_list.index(i)
            q4 = i.replace('Q4-', '')
            q4 = int(q4)
            time_list.pop(index)
            time_list.insert(q2, index)
    return time_list

# %%
path = os.path.join('OECD_data', 'broadband.csv')

with open(path) as csv_file:
    og_broadband_df = pd.read_csv(csv_file)
og_bb_df = og_broadband_df[['Country', 'VAR', 'Time', 'Value', 'Unit']]

# %%
path = os.path.join('OECD_data', 'mean2median_wealth.csv')

with open(path) as csv_file:
    wealth_dist = pd.read_csv(csv_file)
wealth_dist
# Out:
#     ï»¿"COUNTRY"    Country    VAR  \
# 0            AUS  Australia  T3AC2
# 1            AUS  Australia  T3AC2
# 2            AUS  Australia  T3AC3
# 3            AUS  Australia  T3AC3
# 4            AUS  Australia   T1C5
# ..           ...        ...    ...
# 875          JPN      Japan   T6C7
# 876          JPN      Japan    ST1
# 877          JPN      Japan   ST10
# 878          JPN      Japan    ST5
# 879          JPN      Japan  T3AC2
#
#                                               Variable POPULATION  \
# 0    Mean financial assets per household (current p...         TP
# 1    Mean financial assets per household (current p...         TP
# 2      Mean liabilities per household (current prices)         TP
# 3      Mean liabilities per household (current prices)         TP
# 4       Mean net wealth per household (current prices)         TP
# ..                                                 ...        ...
# 875  Share of individuals with eq. net wealth <50 %...         TP
# ...

# %%
path = os.path.join('OECD_data', 'GERDasGDPpercent_OECD2000_19.csv')

with open(path) as csv_file:
    GERD = pd.read_csv(csv_file)
GERD
# Out:
#       ï»¿"MSTI_VAR"                                     MSTI Variables   COU  \
# 0             G_PPP  Gross Domestic Expenditure on R&D (GERD) at cu...   AUS
# 1             G_PPP  Gross Domestic Expenditure on R&D (GERD) at cu...   AUS
# 2             G_PPP  Gross Domestic Expenditure on R&D (GERD) at cu...   AUS
# 3             G_PPP  Gross Domestic Expenditure on R&D (GERD) at cu...   AUS
# 4             G_PPP  Gross Domestic Expenditure on R&D (GERD) at cu...   AUS
# ...             ...                                                ...   ...
# 96222       C_PPPCT           Total GBARD at constant prices and PPP $  OECD
# 96223       C_PPPCT           Total GBARD at constant prices and PPP $  OECD
# 96224       C_PPPCT           Total GBARD at constant prices and PPP $  OECD
# 96225       C_PPPCT           Total GBARD at constant prices and PPP $  OECD
# 96226       C_PPPCT           Total GBARD at constant prices and PPP $  OECD
#
# ...

# %%
path = os.path.join('OECD_data', 'OECD_FTER&D_2000_19.csv')

with open(path) as csv_file:
    fte_rd = pd.read_csv(csv_file)
fte_rd
## merge dataframes and experiment mergin by year in wealth distribution
# Out:
#       ï»¿"MSTI_VAR"                                     MSTI Variables   COU  \
# 0             G_PPP  Gross Domestic Expenditure on R&D (GERD) at cu...   AUS
# 1             G_PPP  Gross Domestic Expenditure on R&D (GERD) at cu...   AUS
# 2             G_PPP  Gross Domestic Expenditure on R&D (GERD) at cu...   AUS
# 3             G_PPP  Gross Domestic Expenditure on R&D (GERD) at cu...   AUS
# 4             G_PPP  Gross Domestic Expenditure on R&D (GERD) at cu...   AUS
# ...             ...                                                ...   ...
# 96222       C_PPPCT           Total GBARD at constant prices and PPP $  OECD
# 96223       C_PPPCT           Total GBARD at constant prices and PPP $  OECD
# 96224       C_PPPCT           Total GBARD at constant prices and PPP $  OECD
# 96225       C_PPPCT           Total GBARD at constant prices and PPP $  OECD
# 96226       C_PPPCT           Total GBARD at constant prices and PPP $  OECD
#
# ...

# %%
path = os.path.join('OECD_data', 'OECD_patentinfo_1999_2017.csv')

with open(path) as csv_file:
    patent_df = pd.read_csv(csv_file)
patent_df
# Out:
#       ï»¿"KINDPATENT"                     Patent office   KINDCOOP  \
# 0               EPO_A    Patent applications to the EPO    FOR_APP
# 1               EPO_A    Patent applications to the EPO    FOR_APP
# 2               EPO_A    Patent applications to the EPO    FOR_APP
# 3               EPO_A    Patent applications to the EPO    FOR_APP
# 4               EPO_A    Patent applications to the EPO    FOR_APP
# ...               ...                               ...        ...
# 18934         USPTO_A  Patent applications to the USPTO  FOR_INV_S
# 18935         USPTO_A  Patent applications to the USPTO  FOR_INV_S
# 18936         USPTO_A  Patent applications to the USPTO  FOR_INV_S
# 18937         USPTO_A  Patent applications to the USPTO  FOR_INV_S
# 18938         USPTO_A  Patent applications to the USPTO  FOR_INV_S
#
#       Type of International Cooperation in Patenting LOCATION    Country  \
# 0           Foreign ownership of domestic inventions      AUS  Australia
# ...

# %%
path = os.path.join('OECD_data', 'researchers_annual_growth.csv')

with open(path) as csv_file:
    research_df = pd.read_csv(csv_file)
research_df
# Out:
#       ï»¿"MSTI_VAR"                                     MSTI Variables   COU  \
# 0             G_PPP  Gross Domestic Expenditure on R&D (GERD) at cu...   AUS
# 1             G_PPP  Gross Domestic Expenditure on R&D (GERD) at cu...   AUS
# 2             G_PPP  Gross Domestic Expenditure on R&D (GERD) at cu...   AUS
# 3             G_PPP  Gross Domestic Expenditure on R&D (GERD) at cu...   AUS
# 4             G_PPP  Gross Domestic Expenditure on R&D (GERD) at cu...   AUS
# ...             ...                                                ...   ...
# 96222       C_PPPCT           Total GBARD at constant prices and PPP $  OECD
# 96223       C_PPPCT           Total GBARD at constant prices and PPP $  OECD
# 96224       C_PPPCT           Total GBARD at constant prices and PPP $  OECD
# 96225       C_PPPCT           Total GBARD at constant prices and PPP $  OECD
# 96226       C_PPPCT           Total GBARD at constant prices and PPP $  OECD
#
# ...

# %%
## merge dataframes and experiment mergin by year in wealth distribution
